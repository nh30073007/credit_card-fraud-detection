# %%
#separate the fraud and non-fraud transactions

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load the dataset
df = pd.read_csv(r'C:\Users\nh013\Desktop\creditcard.csv\creditcard.csv')

# # Feature 
df = df[['Time','V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class','Amount']]

# Separate fraud and non-fraud transactions
fraud_transactions = df[df['Class'] == 1]
non_fraud_transactions = df[df['Class'] == 0]

# Print the fraud transactions
print("Fraud Transactions:")
print(fraud_transactions)

# Print the non-fraud transactions
print("\nNon-Fraud Transactions:")
print(non_fraud_transactions)



# Create subplots for histogram and density plots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs = axs.flatten()

# Plot histograms and density plots for fraud transactions
sns.histplot(fraud_transactions['Amount'], bins=50, ax=axs[0])
sns.kdeplot(fraud_transactions['Amount'], ax=axs[1])

# Plot histograms and density plots for non-fraud transactions
sns.histplot(non_fraud_transactions['Amount'], bins=50, ax=axs[2])
sns.kdeplot(non_fraud_transactions['Amount'], ax=axs[3])

# Set titles and labels for the plots
axs[0].set_title("Histogram of Fraud Transaction Amount")
axs[1].set_title("Density Plot of Fraud Transaction Amount")
axs[2].set_title("Histogram of Non-Fraud Transaction Amount")
axs[3].set_title("Density Plot of Non-Fraud Transaction Amount")
axs[0].set_xlabel("Transaction Amount")
axs[1].set_xlabel("Transaction Amount")
axs[2].set_xlabel("Transaction Amount")
axs[3].set_xlabel("Transaction Amount")
axs[0].set_ylabel("Count")
axs[1].set_ylabel("Density")
axs[2].set_ylabel("Count")
axs[3].set_ylabel("Density")

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Fraud Transactions:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 541    -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623     0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920    0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108   -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329    1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Class  Amount
# 541     0.320198  0.044519  0.177840  0.261145 -0.143276      1    0.00
# 623    -0.293803  0.279798 -0.145362 -0.252773  0.035764      1  529.00
# 4920   -0.087330 -0.156114 -0.542628  0.039566 -0.153029      1  239.93
# 6108   -0.053502  0.252405 -0.657488 -0.827136  0.849573      1   59.00
# 6329   -1.632653  1.488901  0.566797 -0.010016  0.146793      1    1.00
# ...          ...       ...       ...       ...       ...    ...     ...
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968      1  390.00
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637      1    0.76
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361      1   77.89
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700      1  245.00
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309      1   42.53
#
# [492 rows x 31 columns]
#
# Non-Fraud Transactions:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Class  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053      0
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724      0
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458      0
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731      0
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527      0
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561      0
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533      0
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649      0
#
#         Amount
# 0       149.62
# 1         2.69
# 2       378.66
# 3       123.50
# 4        69.99
# ...        ...
# 284802    0.77
# 284803   24.79
# 284804   67.88
# 284805   10.00
# 284806  217.00
#
# [284315 rows x 31 columns]

# %%
# preprocess step 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load the dataset
df = pd.read_csv(r'C:\Users\nh013\Desktop\creditcard.csv\creditcard.csv')

# Drop the Time column
df.drop('Time', axis=1, inplace=True)

# Handle missing values
df.dropna(inplace=True)

# One-hot encode the Class column
df = pd.get_dummies(df, columns=['Class'], drop_first=True)

# Normalize the Amount column using z-score normalization
df['Amount'] = (df['Amount'] - df['Amount'].mean()) / df['Amount'].std()

# Separate fraud and non-fraud transactions
fraud_transactions = df[df['Class_1'] == 1]
non_fraud_transactions = df[df['Class_1'] == 0]

# Print the fraud transactions
print("Fraud Transactions:")
print(fraud_transactions)

# Print the non-fraud transactions
print("\nNon-Fraud Transactions:")
print(non_fraud_transactions)

# Create subplots for histogram and density plots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs = axs.flatten()

# Plot histograms and density plots for fraud transactions
sns.histplot(fraud_transactions['Amount'], bins=50, ax=axs[0])
sns.kdeplot(fraud_transactions['Amount'], ax=axs[1])

# Plot histograms and density plots for non-fraud transactions
sns.histplot(non_fraud_transactions['Amount'], bins=50, ax=axs[2])
sns.kdeplot(non_fraud_transactions['Amount'], ax=axs[3])

# Set titles and labels for the plots
axs[0].set_title("Histogram of Fraud Transaction Amount")
axs[1].set_title("Density Plot of Fraud Transaction Amount")
axs[2].set_title("Histogram of Non-Fraud Transaction Amount")
axs[3].set_title("Density Plot of Non-Fraud Transaction Amount")
axs[0].set_xlabel("Transaction Amount")
axs[1].set_xlabel("Transaction Amount")
axs[2].set_xlabel("Transaction Amount")
axs[3].set_xlabel("Transaction Amount")
axs[0].set_ylabel("Count")
axs[1].set_ylabel("Density")
axs[2].set_ylabel("Count")
axs[3].set_ylabel("Density")

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Fraud Transactions:
#               V1        V2        V3        V4        V5        V6        V7  \
# 541    -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623    -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920   -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108   -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329    1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#               V8        V9       V10  ...       V21       V22       V23  \
# 541     1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 623    -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 4920   -0.399147 -0.238253 -1.525412  ... -0.294166 -0.932391  0.172726
# 6108   -0.248778 -0.247768 -4.801637  ...  0.573574  0.176968 -0.436207
# 6329   -0.496358 -1.282858 -2.447469  ... -0.379068 -0.704181 -0.656805
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863  0.697211 -2.064945 -5.587794  ...  0.778584 -0.319189  0.639419
# 280143  0.248525 -1.127396 -3.232153  ...  0.370612  0.028234 -0.145640
# 280149  1.210158 -0.652250 -3.463891  ...  0.751826  0.834108  0.190944
# 281144  1.058733 -1.632333 -5.245984  ...  0.583276 -0.269209 -0.456108
# 281674 -0.068384  0.577829 -0.888722  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28    Amount  Class_1
# 541     0.320198  0.044519  0.177840  0.261145 -0.143276 -0.353229        1
# 623    -0.293803  0.279798 -0.145362 -0.252773  0.035764  1.761755        1
# 4920   -0.087330 -0.156114 -0.542628  0.039566 -0.153029  0.606030        1
# 6108   -0.053502  0.252405 -0.657488 -0.827136  0.849573 -0.117342        1
# 6329   -1.632653  1.488901  0.566797 -0.010016  0.146793 -0.349231        1
# ...          ...       ...       ...       ...       ...       ...      ...
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  1.206022        1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637 -0.350190        1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361 -0.041818        1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  0.626301        1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309 -0.183190        1
#
# [492 rows x 30 columns]
#
# Non-Fraud Transactions:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.244964
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.342474
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.160684
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.140534
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153 -0.073403
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731 -0.350150
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527 -0.254116
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561 -0.081839
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533 -0.313248
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  0.514354
#
#         Class_1
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 284802        0
# 284803        0
# 284804        0
# 284805        0
# 284806        0
#
# [284315 rows x 30 columns]

# %%
# SMOTE used to handle imbalanced clasess and train logistic regression model

import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix


# Load the dataset
df = pd.read_csv(r'C:\Users\nh013\Desktop\creditcard.csv\creditcard.csv')

# Drop the Time column
df.drop('Time', axis=1, inplace=True)

# Handle missing values
df.dropna(inplace=True)

# One-hot encode the Class column
df = pd.get_dummies(df, columns=['Class'], drop_first=True)

# Normalize the Amount column using z-score normalization
df['Amount'] = (df['Amount'] - df['Amount'].mean()) / df['Amount'].std()

# Separate features and target
X = df.drop('Class_1', axis=1)
y = df['Class_1']

# Perform SMOTE to handle imbalanced classes
smote = SMOTE()
X, y = smote.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[83006  2143]
#  [ 7158 78282]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     85149
#            1       0.97      0.92      0.94     85440
#
#     accuracy                           0.95    170589
#    macro avg       0.95      0.95      0.95    170589
# weighted avg       0.95      0.95      0.95    170589

# %%
# visualize fraud and non fraud transection

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix


# Load the dataset
df = pd.read_csv(r'C:\Users\nh013\Desktop\creditcard.csv\creditcard.csv')

# Drop the Time column
df.drop('Time', axis=1, inplace=True)

# Handle missing values
df.dropna(inplace=True)

# One-hot encode the Class column
df = pd.get_dummies(df, columns=['Class'], drop_first=True)

# Normalize the Amount column using z-score normalization
df['Amount'] = (df['Amount'] - df['Amount'].mean()) / df['Amount'].std()

# Separate fraud and non-fraud transactions
fraud_transactions = df[df['Class_1'] == 1]
non_fraud_transactions = df[df['Class_1'] == 0]

# Create a scatter plot to visualize fraud and non-fraud transactions
plt.scatter(fraud_transactions['V1'], fraud_transactions['V2'], color='red', s=2, label='Fraud')
plt.scatter(non_fraud_transactions['V1'], non_fraud_transactions['V2'], color='blue', s=2, label='Non-Fraud')
plt.legend()
plt.show()

# Separate features and target
X = df.drop('Class_1', axis=1)
y = df['Class_1']

# Perform SMOTE to handle imbalanced classes
smote = SMOTE()
X, y = smote.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[82994  2155]
#  [ 7124 78316]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     85149
#            1       0.97      0.92      0.94     85440
#
#     accuracy                           0.95    170589
#    macro avg       0.95      0.95      0.95    170589
# weighted avg       0.95      0.95      0.95    170589

# %%
# using MLPClassifier algorithm ...

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Load the dataset
df = pd.read_csv(r'C:\Users\nh013\Desktop\creditcard.csv\creditcard.csv')

# Drop the Time column
df.drop('Time', axis=1, inplace=True)

# Handle missing values
df.dropna(inplace=True)

# One-hot encode the Class column
df = pd.get_dummies(df, columns=['Class'], drop_first=True)

# Normalize the Amount column using z-score normalization
df['Amount'] = (df['Amount'] - df['Amount'].mean()) / df['Amount'].std()

# Separate features and target
X = df.drop('Class_1', axis=1)
y = df['Class_1']

# Perform SMOTE to handle imbalanced classes
smote = SMOTE()
X, y = smote.fit_resample(X, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a neural network model
model = MLPClassifier(hidden_layer_sizes=(64, 32, 16), max_iter=500, random_state=42)
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Confusion Matrix:
# [[85105    44]
#  [   34 85406]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85149
#            1       1.00      1.00      1.00     85440
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
